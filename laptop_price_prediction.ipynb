# %%
from google.colab import drive
drive.mount('/content/drive/')
import numpy as np
import pandas as pd
# Out:
# Mounted at /content/drive/

# %%
path="/content/drive/MyDrive/data sets/laptop_data.csv"
temp_df=""
df=pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape #dimension of dataset i.e. rows and columns
# Out:
# (1303, 12)

# %%
df.info() #info about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum() #checking duplicated rows
# Out:
# 0

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram'] = df['Ram'].str.replace("GB","") #removing string so that the value type can be converted to string

# %%
df['Weight'] = df['Weight'].str.replace("kg","")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df['Ram']=df['Ram'].astype(int)
df['Weight']=df['Weight'].astype(float) #after removing gb and kg we convert datatype to int for better use in future
df['Price']=df['Price'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int64
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 112.1+ KB

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378
# 1        Intel HD Graphics 6000  macOS    1.34   47895
# 2         Intel HD Graphics 620  No OS    1.86   30636
# ...

# %%
import seaborn as sns

# %%
sns.displot(df['Price']) #how many laptops are in a particular price range

# %%
sns.barplot(y=df['Company'],x=df['Price']) #comparison of price vs company

# %%
df['TypeName'].value_counts().plot(kind='bar') #what kind pf laptop is most common

# %%
sns.barplot(x=df['Price'],y=df['TypeName']) # comparison of price vs Type of laptop

# %%
df['Inches'].value_counts().plot(kind='bar') # wht size of screen is most common

# %%
df.shape
# Out:
# (1303, 11)

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
#creating a new column for touch screen laptops bor better understanding of the data_set
df['Touchscreen']=df['ScreenResolution'].apply(lambda x :1 if 'Touchscreen' in x else 0 ) #this is feature engineering

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0
# ...

# %%
df['Touchscreen'].value_counts() # no. of touchscreen laptops vs non tuchscreen laptops
# Out:
# 0    1111
# 1     192
# Name: Touchscreen, dtype: int64

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])

# %%
#we will do feature engineering again to checjk wether laptops have ips pannel or not
df['Panel']=df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  Panel
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0      1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0      0
# ...

# %%
sns.barplot(x=df['Panel'],y=df['Price'])

# %%
df['Panel'].value_counts().plot(kind='bar')

# %%
#now we create a new column for resolution in this we will create 2 new colums one for x axis another for y axis
temp_df = pd.DataFrame(df['ScreenResolution'].str.split('x',n=1,expand=True))
temp_df.head()
# Out:
#                                0     1
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
df['Xres']=temp_df[0]
df['Yres']=temp_df[1]
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  Panel  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0      1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0      0
# ...

# %%
df['Xres']=df['Xres'].replace(',',"").str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  Panel  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0      1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0      0
# ...

# %%
df['Xres']=df['Xres'].astype(int)
df['Yres']=df['Yres'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int64
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   int64
#  11  Touchscreen       1303 non-null   int64
#  12  Panel             1303 non-null   int64
#  13  Xres              1303 non-null   int64
#  14  Yres              1303 non-null   int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 152.8+ KB

# %%
#we will create a new colum by the name ppi which is root((x)^2+(y)^2) divided by inches
df['ppi']=(((df['Xres']**2+df["Yres"]**2)**0.5)/df["Inches"]).astype(float)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  Panel  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0      1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0      0
# ...

# %%
df.corr()['Price']
# Out:
# Inches         0.068196
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Panel          0.252207
# Xres           0.556529
# Yres           0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
#now we dont need screen resolution column so we will drop it
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight   Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37   71378
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34   47895
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86   30636
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83  135195
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37   96095
#
#    Touchscreen  Panel  Xres  Yres         ppi
# 0            0      1  2560  1600  226.983005
# ...

# %%
#now we dont need Xres and Yres as we have ppi value so we will drop it
df.drop(columns=['Xres'],inplace=True)
df.drop(columns=['Yres'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight   Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37   71378
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34   47895
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86   30636
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83  135195
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37   96095
#
#    Touchscreen  Panel         ppi
# 0            0      1  226.983005
# 1            0      0  127.677940
# ...

# %%
#now we have to work on system enginerring of Cpu
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu Name']=df['Cpu'].apply(lambda x :" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight   Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37   71378
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34   47895
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86   30636
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83  135195
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37   96095
#
#    Touchscreen  Panel         ppi       Cpu Name
# 0            0      1  226.983005  Intel Core i5
# ...

# %%
def get_processor(text):
  if text=='Intel Core i3' or text == 'Intel Core i5' or text == 'Intel Core i7':
    return text
  else:
    if text.split()[0]=='Intel':
      return "Other Intel Processor"
    else:
      return "AMD Processor"

df['Cpu brand']=df['Cpu Name'].apply(get_processor)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight   Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37   71378
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34   47895
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86   30636
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83  135195
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37   96095
#
#    Touchscreen  Panel         ppi       Cpu Name      Cpu brand
# 0            0      1  226.983005  Intel Core i5  Intel Core i5
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')

# %%
#comparing price to processor cpu brand
sns.barplot(x=df['Price'],y=df['Cpu brand'])

# %%
#now we will drop Cpu and Cpu name
df.drop(columns=['Cpu'],inplace=True)

# %%
df.drop(columns=['Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram               Memory  \
# 0   Apple  Ultrabook    13.3    8            128GB SSD
# 1   Apple  Ultrabook    13.3    8  128GB Flash Storage
# 2      HP   Notebook    15.6    8            256GB SSD
# 3   Apple  Ultrabook    15.4   16            512GB SSD
# 4   Apple  Ultrabook    13.3    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  Panel  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0      1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0      0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0      0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0      1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0      1
#
#           ppi      Cpu brand
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# 4  226.983005  Intel Core i5

# %%
#comparison of ram and price
df.corr()['Price']
# Out:
# Inches         0.068196
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Panel          0.252207
# ppi            0.473487
# Name: Price, dtype: float64

# %%
#plotting relation between ram and price
sns.barplot(x=df['Ram'],y=df['Price'])

# %%
df['Ram'].value_counts().plot(kind='bar') #most sold ram in market

# %%
#now we will work with storage
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram             Memory  \
# 0   Apple  Ultrabook    13.3    8            128 SSD
# 1   Apple  Ultrabook    13.3    8  128 Flash Storage
# 2      HP   Notebook    15.6    8            256 SSD
# 3   Apple  Ultrabook    15.4   16            512 SSD
# 4   Apple  Ultrabook    13.3    8            256 SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  Panel  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0      1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0      0
# 2         Intel HD Graphics 620  No OS    1.86   30636            0      0
# 3            AMD Radeon Pro 455  macOS    1.83  135195            0      1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095            0      1
#
#           ppi      Cpu brand  HDD  SSD  Hybrid  Flash_Storage
# 0  226.983005  Intel Core i5    0  128       0              0
# 1  127.677940  Intel Core i5    0    0       0            128
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches  Ram                           Gpu  OpSys  \
# 0   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 640  macOS
# 1   Apple  Ultrabook    13.3    8        Intel HD Graphics 6000  macOS
# 2      HP   Notebook    15.6    8         Intel HD Graphics 620  No OS
# 3   Apple  Ultrabook    15.4   16            AMD Radeon Pro 455  macOS
# 4   Apple  Ultrabook    13.3    8  Intel Iris Plus Graphics 650  macOS
#
#    Weight   Price  Touchscreen  Panel         ppi      Cpu brand  HDD  SSD  \
# 0    1.37   71378            0      1  226.983005  Intel Core i5    0  128
# 1    1.34   47895            0      0  127.677940  Intel Core i5    0    0
# 2    1.86   30636            0      0  141.211998  Intel Core i5    0  256
# 3    1.83  135195            0      1  220.534624  Intel Core i7    0  512
# 4    1.37   96095            0      1  226.983005  Intel Core i5    0  256
#
#    Hybrid  Flash_Storage
# 0       0              0
# 1       0            128
# ...

# %%
#we will corelate storage with price
df.corr()['Price']
# Out:
# Inches           0.068196
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Panel            0.252207
# ppi              0.473487
# HDD             -0.096442
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
#we dont need hybrid or flash storage so we will drop them reason low corelation similarly we will drop inches as well (low corelation to price)
df.drop(columns=['Inches'],inplace=True)
df.drop(columns=['Hybrid'],inplace=True)
df.drop(columns=['Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#     Price  Touchscreen  Panel         ppi      Cpu brand  HDD  SSD
# 0   71378            0      1  226.983005  Intel Core i5    0  128
# 1   47895            0      0  127.677940  Intel Core i5    0    0
# 2   30636            0      0  141.211998  Intel Core i5    0  256
# 3  135195            0      1  220.534624  Intel Core i7    0  512
# 4   96095            0      1  226.983005  Intel Core i5    0  256

# %%
df['OpSys'].value_counts().plot(kind='bar')

# %%
#working with the gpu column
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
#getting Gpu Brand
df['Gpu brand']=df['Gpu'].apply(lambda x: x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#     Price  Touchscreen  Panel         ppi      Cpu brand  HDD  SSD Gpu brand
# 0   71378            0      1  226.983005  Intel Core i5    0  128     Intel
# 1   47895            0      0  127.677940  Intel Core i5    0    0     Intel
# 2   30636            0      0  141.211998  Intel Core i5    0  256     Intel
# 3  135195            0      1  220.534624  Intel Core i7    0  512       AMD
# 4   96095            0      1  226.983005  Intel Core i5    0  256     Intel

# %%
#most selling Gpu brand
df['Gpu brand'].value_counts().plot(kind='bar')

# %%
df[df['Gpu brand']=='ARM']
# Out:
#       Company            TypeName  Ram                Gpu      OpSys  Weight  \
# 1191  Samsung  2 in 1 Convertible    4  ARM Mali T860 MP4  Chrome OS    1.15
#
#       Price  Touchscreen  Panel       ppi      Cpu brand  HDD  SSD Gpu brand
# 1191  35111            1      1  234.5074  AMD Processor    0    0       ARM

# %%
df.drop(df.index[1191], inplace=True)

# %%
df.shape
# Out:
# (1302, 14)

# %%
df['Gpu brand'].value_counts().plot(kind='bar')

# %%
#comparing price to gpu
sns.barplot(x=df['Gpu brand'],y=df['Price'])

# %%
#now we can drop gpu column
df.drop(columns=['Gpu'],inplace=True)

# %%
df.tail()
# Out:
#      Company            TypeName  Ram       OpSys  Weight  Price  Touchscreen  \
# 1298  Lenovo  2 in 1 Convertible    4  Windows 10    1.80  33992            1
# 1299  Lenovo  2 in 1 Convertible   16  Windows 10    1.30  79866            1
# 1300  Lenovo            Notebook    2  Windows 10    1.50  12201            0
# 1301      HP            Notebook    6  Windows 10    2.19  40705            0
# 1302    Asus            Notebook    4  Windows 10    2.20  19660            0
#
#       Panel         ppi              Cpu brand   HDD  SSD Gpu brand
# 1298      1  157.350512          Intel Core i7     0  128     Intel
# 1299      1  276.053530          Intel Core i7     0  512     Intel
# 1300      0  111.935204  Other Intel Processor     0    0     Intel
# 1301      0  100.454670          Intel Core i7  1000    0       AMD
# 1302      0  100.454670  Other Intel Processor   500    0     Intel

# %%
#comparing weight and price
df['Weight'].value_counts()
# Out:
# 2.20    126
# 2.10     58
# 2.00     45
# 2.40     44
# 2.30     41
#        ...
# 4.50      1
# 1.14      1
# 3.80      1
# 2.26      1
# 2.34      1
# Name: Weight, Length: 171, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')

# %%
#reducing categories that is windows in one mac in one like this
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight   Price  Touchscreen  Panel  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378            0      1
# 1   Apple  Ultrabook    8  macOS    1.34   47895            0      0
# 2      HP   Notebook    8  No OS    1.86   30636            0      0
# 3   Apple  Ultrabook   16  macOS    1.83  135195            0      1
# 4   Apple  Ultrabook    8  macOS    1.37   96095            0      1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight   Price  Touchscreen  Panel  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378            0      1
# 1   Apple  Ultrabook    8  macOS    1.34   47895            0      0
# 2      HP   Notebook    8  No OS    1.86   30636            0      0
# 3   Apple  Ultrabook   16  macOS    1.83  135195            0      1
# 4   Apple  Ultrabook    8  macOS    1.37   96095            0      1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
def operating(text):
  if text == "Windows 7" or text == "Windows 10" or text == "Windows 10 S":
    return "Windows"
  if text == "macOS" or text == "Mac OS X":
    return "Mac"
  else:
    return "NO OS/Android/Linux"

# %%
df['OS']=df['OpSys'].apply(operating)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight   Price  Touchscreen  Panel  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378            0      1
# 1   Apple  Ultrabook    8  macOS    1.34   47895            0      0
# 2      HP   Notebook    8  No OS    1.86   30636            0      0
# 3   Apple  Ultrabook   16  macOS    1.83  135195            0      1
# 4   Apple  Ultrabook    8  macOS    1.37   96095            0      1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand                   OS
# 0  226.983005  Intel Core i5    0  128     Intel                  Mac
# 1  127.677940  Intel Core i5    0    0     Intel                  Mac
# 2  141.211998  Intel Core i5    0  256     Intel  NO OS/Android/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                  Mac
# 4  226.983005  Intel Core i5    0  256     Intel                  Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight   Price  Touchscreen  Panel         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378            0      1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895            0      0  127.677940
# 2      HP   Notebook    8    1.86   30636            0      0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195            0      1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095            0      1  226.983005
#
#        Cpu brand  HDD  SSD Gpu brand                   OS
# 0  Intel Core i5    0  128     Intel                  Mac
# 1  Intel Core i5    0    0     Intel                  Mac
# 2  Intel Core i5    0  256     Intel  NO OS/Android/Linux
# 3  Intel Core i7    0  512       AMD                  Mac
# 4  Intel Core i5    0  256     Intel                  Mac

# %%
sns.heatmap(df.corr())

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])

# %%
x = df.drop(columns=['Price'])

# %%
x
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Panel         ppi  \
# 0      Apple           Ultrabook    8    1.37            0      1  226.983005
# 1      Apple           Ultrabook    8    1.34            0      0  127.677940
# 2         HP            Notebook    8    1.86            0      0  141.211998
# 3      Apple           Ultrabook   16    1.83            0      1  220.534624
# 4      Apple           Ultrabook    8    1.37            0      1  226.983005
# ...      ...                 ...  ...     ...          ...    ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1      1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1      1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0      0  111.935204
# 1301      HP            Notebook    6    2.19            0      0  100.454670
# 1302    Asus            Notebook    4    2.20            0      0  100.454670
#
# ...

# %%
df['OS'].value_counts().plot(kind="bar")

# %%
y= np.log(df['Price'])
y
# Out:
# 0       11.175745
# 1       10.776766
# 2       10.329931
# 3       11.814473
# 4       11.473093
#           ...
# 1298    10.433880
# 1299    11.288106
# 1300     9.409273
# 1301    10.614106
# 1302     9.886341
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.15,random_state=2)

# %%
x_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Panel  \
# 183   Toshiba            Notebook    8    2.00            0      0
# 1141      MSI              Gaming    8    2.40            0      0
# 1049     Asus             Netbook    4    1.20            0      0
# 1020     Dell  2 in 1 Convertible    4    2.08            1      1
# 878      Dell            Notebook    4    2.18            0      0
# ...       ...                 ...  ...     ...          ...    ...
# 466      Acer            Notebook    4    2.20            0      0
# 299      Asus           Ultrabook   16    1.63            0      0
# 493      Acer            Notebook    8    2.20            0      0
# 527    Lenovo            Notebook    8    2.20            0      0
# 1193    Apple           Ultrabook    8    0.92            0      1
#
#              ppi              Cpu brand   HDD  SSD Gpu brand  \
# 183   100.454670          Intel Core i5     0  128     Intel
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression

# %%
# LINEAR REGRESSION
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8073285593440435
# MAE 0.21018098624043896

# %%
sns.barplot(y=df['Price'],x=df['OS'])

# %%
#KNN REGRESSOR (K NEARESR NEIGHBOUR)
from sklearn.neighbors import KNeighborsRegressor

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2= KNeighborsRegressor(n_neighbors=3)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred=pipe.predict(x_test)

R2_SCORE=r2_score(y_test,y_pred)
print("R2_SCORE is ",R2_SCORE)
# Out:
# R2_SCORE is  0.8021505378799195
